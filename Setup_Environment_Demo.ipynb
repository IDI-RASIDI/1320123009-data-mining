# %% [markdown]
# <a href="https://colab.research.google.com/github/IDI-RASIDI/1320123009-data-mining/blob/main/Setup_Environment_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Idi-Rasidi/1320123009-data-mining
# Out:
# Cloning into '1320123009-data-mining'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 15 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 4.52 KiB | 661.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
import pandas as pd
print("Versi Pandas yang terinstall:", pd.__version__)
print("Hello, Data Mining!")
# Out:
# Versi Pandas yang terinstall: 2.2.2
# Hello, Data Mining!
